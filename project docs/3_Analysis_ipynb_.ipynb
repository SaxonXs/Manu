# %%
import pandas as pd

# %%
df = pd.read_excel('/content/Данные для анализа.xlsx', sheet_name='Лист1')
# Out:
# <ipython-input-6-42f85a546e80>:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   df = pd.read_excel('/content/Данные для анализа.xlsx', sheet_name='Лист1')

# %%
df
# Out:
#          id           collected  channel      программа_канала1 режим_канала1  \
# 0      5116 2023-12-06 16:14:28        5          /NC/.~mdi/ch1    Стр. ввода
# 1      5117 2023-12-06 16:14:58        3  /NC/examples/05_09.nc          Авто
# 2      5118 2023-12-06 16:14:58        5          /NC/.~mdi/ch1    Стр. ввода
# 3      5119 2023-12-06 16:15:29        3                    NaN          Авто
# 4      5120 2023-12-06 16:15:29        5          /NC/.~mdi/ch1    Стр. ввода
# ...     ...                 ...      ...                    ...           ...
# 14201  5111 2023-12-06 16:13:27        3  /NC/examples/05_04.nc          Авто
# 14202  5112 2023-12-06 16:13:27        5          /NC/.~mdi/ch1    Стр. ввода
# 14203  5113 2023-12-06 16:13:58        3  /NC/examples/05_06.nc          Авто
# 14204  5114 2023-12-06 16:13:58        5          /NC/.~mdi/ch1    Стр. ввода
# 14205  5115 2023-12-06 16:14:28        3  /NC/examples/05_07.nc          Авто
#
# ...

# %%
df_3 = df[df['channel'] == 3]
df_5 = df[df['channel'] == 5]

# %%
df_5
# Out:
#          id               collected  channel программа_канала1 режим_канала1  \
# 0      5116 2023-12-06 16:14:28.000        5     /NC/.~mdi/ch1    Стр. ввода
# 2      5118 2023-12-06 16:14:58.000        5     /NC/.~mdi/ch1    Стр. ввода
# 4      5120 2023-12-06 16:15:29.000        5     /NC/.~mdi/ch1    Стр. ввода
# 6      5122 2023-12-06 16:15:59.000        5     /NC/.~mdi/ch1    Стр. ввода
# 8      5124 2023-12-06 16:16:30.000        5     /NC/.~mdi/ch1    Стр. ввода
# ...     ...                     ...      ...               ...           ...
# 14196  5106 2023-12-06 16:11:56.063        5     /NC/.~mdi/ch1    Стр. ввода
# 14198  5108 2023-12-06 16:12:26.000        5     /NC/.~mdi/ch1    Стр. ввода
# 14200  5110 2023-12-06 16:12:57.000        5     /NC/.~mdi/ch1    Стр. ввода
# 14202  5112 2023-12-06 16:13:27.000        5     /NC/.~mdi/ch1    Стр. ввода
# 14204  5114 2023-12-06 16:13:58.000        5     /NC/.~mdi/ch1    Стр. ввода
#
# ...

# %%
df_3['режим_канала1'].value_counts().sort_values().plot(kind='bar', figsize = (20,8), title = 'режим_канала1 для 3')
# Out:
# <Axes: title={'center': 'режим_канала1 для 3'}>

# %%
df_3['статус_канала1'].value_counts().sort_values().plot(kind='bar', figsize = (20,8), title = 'статус_канала1 для 3')
# Out:
# <Axes: title={'center': 'статус_канала1 для 3'}>

# %%
df_5['режим_канала1'].value_counts().sort_values().plot(kind='bar', figsize = (20,8), title = 'режим_канала1 для 5')
# Out:
# <Axes: title={'center': 'режим_канала1 для 5'}>

# %%
df_5['статус_канала1'].value_counts().sort_values().plot(kind='bar', figsize = (20,8), title = 'статус_канала1 для 5')
# Out:
# <Axes: title={'center': 'статус_канала1 для 5'}>

# %%
df_3['программа_канала1'].value_counts().sort_values().plot(kind='bar', figsize = (20,8), title = 'программа_канала1 для 3')
# Out:
# <Axes: title={'center': 'программа_канала1 для 3'}>

# %%
df_5['программа_канала1'].value_counts().sort_values().plot(kind='bar', figsize = (20,8), title = 'программа_канала1 для 5')
# Out:
# <Axes: title={'center': 'программа_канала1 для 5'}>
